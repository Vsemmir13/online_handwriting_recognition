# %%
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, PROJECT_ROOT)
sys.dont_write_bytecode = True

from MODEL.processing_dataset.reader import IAMReader
from MODEL.constants import SPLIT
import random
import pandas as pd
from MODEL.processing_dataset.base_classes import *

# %%
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
PROJECT_ROOT
# Out:
# '/Users/egorleontenkov/Desktop/Arcticle/REALISATION_PROJECT'

# %%
reader = IAMReader(SPLIT.TEST)
samples = reader.get_samples()
sample = random.choice(samples)
# Out:
# Count missing files: 999
# Ratio missing files: 0.25914396887159535

# %%
pts = sample.pointset
pts.plot_both()
pts, sample.get_ground_truth_text()
# Out:
# (<PointSet w=2707 h=275 points_len=500>, 'is " to twist or pervert " . ')

# %%
pts.slope_correction()
pts.plot_points()
pts
# Out:
# <PointSet w=2707 h=275 points_len=500>

# %%
pts.normalize_points()
pts.plot_points()
pts
# Out:
# <PointSet w=2707 h=275 points_len=500>

# %%
pts.down_sample_angle(cos_th=0.975)
pts.plot_points()
pts
# Out:
# <PointSet w=2707 h=275 points_len=322>

# %%
pts.resample_distance(d=0.33)
pts.plot_points()

# %%
pts.up_sample_short_stroke(n=10)
pts.plot_points()
pts
# Out:
# <PointSet w=2707 h=275 points_len=401>

# %%
pts.down_sample_distance(d_th=0.2)
pts.plot_points()
pts
# Out:
# <PointSet w=2707 h=275 points_len=355>
